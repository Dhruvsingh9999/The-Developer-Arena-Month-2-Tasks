# %% [markdown]
# <h3 style=color:orange>Week 5: Exploratory Data Analysis (EDA)</h3>

# %%
# Week 5 – Exploratory Data Analysis (EDA)
# Dataset: Mock Iris Dataset
# Objective: Summary stats, correlation, visualizations, insights

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style
sns.set(style="whitegrid")

# Create mock Iris-like dataset
np.random.seed(42)
mock_data = pd.DataFrame({
    "sepal_length": np.random.normal(5.8, 0.4, 150),
    "sepal_width": np.random.normal(3.0, 0.3, 150),
    "petal_length": np.random.normal(3.7, 1.5, 150),
    "petal_width": np.random.normal(1.2, 0.5, 150),
    "species": np.random.choice(["setosa", "versicolor", "virginica"], 150)
})

# Preview the data
mock_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0      5.998686     3.075148      2.456507     1.168660   virginica
# 1      5.744694     3.103934      2.859728     1.677571      setosa
# 2      6.059075     2.795993      4.820940     0.707137  versicolor
# 3      6.409212     3.069676      4.615555     1.452023   virginica
# 4      5.706339     3.087922      3.668648     0.934871   virginica

# %%
# Dataset structure
mock_data.info()

# Descriptive statistics
mock_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.767069     3.021369      3.782468     1.151021
# std        0.376937     0.306514      1.424296     0.485346
# min        4.752102     2.027620      0.514156    -0.035822
# 25%        5.532411     2.793093      2.800918     0.819234
# 50%        5.778433     3.042670      3.753618     1.129101
# 75%        5.996373     3.202569      4.727540     1.468317
# max        6.785297     4.155819      6.984704     2.739440

# %%
mock_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
correlation = mock_data.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(mock_data, hue='species')
plt.show()

# %%
sns.boxplot(x='species', y='sepal_length', data=mock_data, palette='Set2')
plt.title('Sepal Length by Species')
plt.show()
# Out:
# C:\Users\wwwdh\AppData\Local\Temp\ipykernel_6648\2493521111.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_length', data=mock_data, palette='Set2')
